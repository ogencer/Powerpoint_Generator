# %%
import os
import xlwt
import pandas as pd
import numpy as np

# %%
#Change these accordingly.
excel_address = 'C:/Users/ozgur/OneDrive/Masaüstü/c.xlsx'
photo_address = 'C:/Users/ozgur/OneDrive/Masaüstü/PHOTO'

# %%
def surnames(photo):
    file_list = [f for f in os.listdir(photo) if os.path.isfile(os.path.join(photo, f))]
    #print (file_list)
    surnames = []
    for a in file_list:
        split = a.split()
        result = split[-1].split('.')
        surnames.append([result[0], a]) 
        #print([result[0], a])
    return surnames
surnames(photo_address)
# Out:
# [['Sutaria', '20181119_020906 - Vrishin Sutaria.jpg'],
#  ['Balaji',
#   '29790803_957678441055777_1197099658520180187_n - Rishikesh Balaji.jpg'],
#  ['Evangelisti', '636757688923011422 - Madelyn Evangelisti.jpg'],
#  ['Allen', 'Allen, Grant 9-15-17 0044r yrbk - Grant Allen.jpg'],
#  ['Zhao', 'DSC_0951 - Stella Zhao.JPG'],
#  ['King', 'image1 - Connor King.jpeg'],
#  ['Sinha', 'IMG_0237 - Yash Sinha.JPG'],
#  ['Tikoo', 'IMG_0550 - Vaishali Tikoo.jpg'],
#  ['Gao', 'IMG_2478 - Yiwen Gao.JPG'],
#  ['Nassirpour', 'IMG_7690 - Roya Nassirpour.jpg'],
#  ['Ruggiero', 'IMG_7763 - Mia Ruggiero.PNG'],
#  ['Li', 'IMG_9437[362] - Songyue Li.JPG'],
#  ['Lee', 'KakaoTalk_Photo_2016-05-11-00-26-06 - Chang Hun Lee.jpeg'],
#  ['Saina', 'Karen Saina - Midori Saina.jpg'],
#  ['Plumley', 'ML9_8716_0001 - Zachary Plumley.jpg'],
#  ['dai', 'professional photo2_meitu_1 - cindy dai.jpg'],
#  ['Shi', 'profile picture - Rui Shi.JPG'],
#  ['YUAN', 'TLBaIV06T46Ll7fBZxpFyw - XINYI YUAN.jpg']]

# %%
df = pd.read_excel(excel_address)
df.describe()
df['Last Name:'] = df['Last Name:'].apply(lambda x: x.lower())
df['Last Name:'] = df['Last Name:'].apply(lambda x: x.capitalize())
df.columns = df.columns.str.replace('Last Name:','last')

# %%
df['filenames'] = 'default value'
for x in surnames(photo_address):
    y = (x[0].lower()).capitalize()
    address = photo_address + x[1]
    address = address.replace("/", "\\")
    df.loc[df['last'] == y, 'filenames'] = address
    #df[df.last == y, 'file names'] = 'C:/Users/ozgur/OneDrive/Masaüstü/PHOTO/'+x[1]
    #df['Last Name:' == (x[0].lower()).capitalize(), 'file names'] = 'C:/Users/ozgur/OneDrive/Masaüstü/PHOTO/'+x[1]
    #df['file names'] = np.where(df['Last Name:' == x[0].lower].str.lower()==(x[0].lower()), 'C:/Users/ozgur/OneDrive/Masaüstü/PHOTO/'+x[1], ' ')
    #df.drop(columns=['(False, file names)'])
    #df.drop(df.columns[[6]], axis=1, inplace=True)
df
# Out:
#              First Name:         last  \
# 0                  Grant        Allen
# 1                  Linda         Yuan
# 2   Chang Hun (Douglass)          Lee
# 3                   Yash        Sinha
# 4               Vaishali        Tikoo
# 5                    Rui          Shi
# 6                Jingwen          Dai
# 7                 Stella         Zhao
# 8                Vrishin      Sutaria
# 9              Rishikesh       Balaji
# 10               Madelyn  Evangelisti
# 11                Edward           Li
# 12                 Karen        Saina
# 13               Connor          King
# 14                 Yiwen          Gao
# 15                   Mia     Ruggiero
# 16               Zachary      Plumley
# 17                  Roya   Nassirpour
#
#                                      Major(s):       Minor(s):  \
# 0                                   Undeclared               -
# 1                          Business Unassigned               -
# 2                                   Accounting               -
# 3                     Finance and Econometrics  SEE Fellowship
# 4                       Industrial Engineering               -
# 5                            Industrial Design               -
# 6                                   accounting               -
# 7               Molecular and Cellular Biology        Business
# 8                       Mechanical Engineering               -
# 9             Computer Science and Mathematics               -
# 10              Systems Engineering and Design         Spanish
# 11                                        Math               -
# 12                                 Accountancy               -
# 13  Finance, economics, informatics, marketing               -
# 14                                 Accounting                -
# 15                          Marketing and ISIT         Spanish
# 16                      Electrical Engineering        Business
# 17                                  Statistics               -
#
#                 Year                                          filenames
# 0           Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOAllen, G...
# 1           Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOTLBaIV06...
# 2             Senior  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOKakaoTal...
# 3           Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOIMG_0237...
# 4           Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOIMG_0550...
# 5          Sophomore  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOprofile ...
# 6   Graduate Student  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOprofessi...
# 7          Sophomore  C:\Users\ozgur\OneDrive\Masaüstü\PHOTODSC_0951...
# 8           Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTO20181119...
# 9          Sophomore  C:\Users\ozgur\OneDrive\Masaüstü\PHOTO29790803...
# 10          Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTO63675768...
# 11         Sophomore  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOIMG_9437...
# 12  Graduate Student  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOKaren Sa...
# 13          Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOimage1 -...
# 14          Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOIMG_2478...
# 15         Sophomore  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOIMG_7763...
# 16          Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOML9_8716...
# 17          Freshman  C:\Users\ozgur\OneDrive\Masaüstü\PHOTOIMG_7690...

# %%
df.to_excel(excel_address, engine='xlsxwriter')
